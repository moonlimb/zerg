# %%
import os

import pandas as pd

# %%
dir_path = os.environ['ZERG']

rhg_regions = dir_path + 'data/meta_data/iso_map_based_on_rhg_regions.xls'

# %%
iso = pd.read_excel(rhg_regions, sheetname='mapper_iso_to_country_name')

# rhg_regions file updated to include Syria and Kosovo
iso_map = iso[['countryName', 'iso']].set_index('countryName').to_dict()['iso']

# %%
iso
# Out:
#               countryNameWB                    countryNameUNNA  \
# 0               Afghanistan                        Afghanistan
# 1                       NaN                                NaN
# 2                   Albania                            Albania
# 3                   Algeria                            Algeria
# 4            American Samoa                                NaN
# 5                   Andorra                            Andorra
# 6                    Angola                             Angola
# 7                       NaN                           Anguilla
# 8                       NaN                                NaN
# 9       Antigua and Barbuda                Antigua and Barbuda
# 10                Argentina                          Argentina
# 11                  Armenia                            Armenia
# 12                    Aruba                              Aruba
# 13                Australia                          Australia
# 14                  Austria                            Austria
# 15               Azerbaijan                         Azerbaijan
# 16             Bahamas, The                            Bahamas
# 17                  Bahrain                            Bahrain
# 18               Bangladesh                         Bangladesh
# 19                 Barbados                           Barbados
# 20                  Belarus                            Belarus
# 21                  Belgium                            Belgium
# 22                   Belize                             Belize
# 23                    Benin                              Benin
# 24                  Bermuda                            Bermuda
# 25                   Bhutan                             Bhutan
# 26                  Bolivia   Bolivia (Plurinational State of)
# 27                      NaN                                NaN
# 28   Bosnia and Herzegovina             Bosnia and Herzegovina
# 29                 Botswana                           Botswana
# ..                      ...                                ...
# 222                     NaN                           Thailand
# 223                     NaN                        Timor-Leste
# 224                     NaN                               Togo
# 225                     NaN                                NaN
# 226                     NaN                              Tonga
# 227                     NaN                Trinidad and Tobago
# 228                     NaN                            Tunisia
# 229                     NaN                             Turkey
# 230                     NaN                       Turkmenistan
# 231                     NaN           Turks and Caicos Islands
# 232                     NaN                             Tuvalu
# 233                     NaN                                NaN
# 234                     NaN                                NaN
# 235                     NaN               United Arab Emirates
# 236                     NaN                     United Kingdom
# 237                     NaN                      United States
# 238                     NaN                                NaN
# 239                     NaN                            Uruguay
# 240                     NaN                         Uzbekistan
# 241                     NaN                            Vanuatu
# 242                     NaN  Venezuela (Bolivarian Replubc of)
# 243                     NaN                           Viet Nam
# 244                     NaN             British Virgin Islands
# 245                     NaN                                NaN
# 246                     NaN                                NaN
# 247                     NaN                                NaN
# 248                     NaN                              Yemen
# 249                     NaN                             Zambia
# 250                     NaN                           Zanzibar
# 251                     NaN                           Zimbabwe
#
#                               countryName  \
# 0                             Afghanistan
# 1                           Åland Islands
# 2                                 Albania
# 3                                 Algeria
# 4                          American Samoa
# 5                                 Andorra
# 6                                  Angola
# 7                                Anguilla
# 8                              Antarctica
# 9                     Antigua and Barbuda
# 10                              Argentina
# 11                                Armenia
# 12                                  Aruba
# 13                              Australia
# 14                                Austria
# 15                             Azerbaijan
# 16                           Bahamas, The
# 17                                Bahrain
# 18                             Bangladesh
# 19                               Barbados
# 20                                Belarus
# 21                                Belgium
# 22                                 Belize
# 23                                  Benin
# 24                                Bermuda
# 25                                 Bhutan
# 26                                Bolivia
# 27       Bonaire, Sint Eustatius and Saba
# 28                 Bosnia and Herzegovina
# 29                               Botswana
# ..                                    ...
# 222                              Thailand
# 223                           Timor-Leste
# 224                                  Togo
# 225                               Tokelau
# 226                                 Tonga
# 227                   Trinidad and Tobago
# 228                               Tunisia
# 229                                Turkey
# 230                          Turkmenistan
# 231              Turks and Caicos Islands
# 232                                Tuvalu
# 233                                Uganda
# 234                               Ukraine
# 235                  United Arab Emirates
# 236                        United Kingdom
# 237                         United States
# 238  United States Minor Outlying Islands
# 239                               Uruguay
# 240                            Uzbekistan
# 241                               Vanuatu
# 242                             Venezuela
# 243                               Vietnam
# 244              Virgin Islands (British)
# 245                 Virgin Islands (U.S.)
# 246                     Wallis and Futuna
# 247                        Western Sahara
# 248                                 Yemen
# 249                                Zambia
# 250                                   NaN
# 251                              Zimbabwe
#
#                                            isoFullName  iso  numeric
# 0                                          Afghanistan  AFG      4.0
# 1                                        Åland Islands  ALA    248.0
# 2                                              Albania  ALB      8.0
# 3                                              Algeria  DZA     12.0
# 4                                       American Samoa  ASM     16.0
# 5                                              Andorra  AND     20.0
# 6                                               Angola  AGO     24.0
# 7                                             Anguilla  AIA    660.0
# 8                                           Antarctica  ATA     10.0
# 9                                  Antigua and Barbuda  ATG     28.0
# 10                                           Argentina  ARG     32.0
# 11                                             Armenia  ARM     51.0
# 12                                               Aruba  ABW    533.0
# 13                                           Australia  AUS     36.0
# 14                                             Austria  AUT     40.0
# 15                                          Azerbaijan  AZE     31.0
# 16                                             Bahamas  BHS     44.0
# 17                                             Bahrain  BHR     48.0
# 18                                          Bangladesh  BGD     50.0
# 19                                            Barbados  BRB     52.0
# 20                                             Belarus  BLR    112.0
# 21                                             Belgium  BEL     56.0
# 22                                              Belize  BLZ     84.0
# 23                                               Benin  BEN    204.0
# 24                                             Bermuda  BMU     60.0
# 25                                              Bhutan  BTN     64.0
# 26                    Bolivia (Plurinational State of)  BOL     68.0
# 27                    Bonaire, Sint Eustatius and Saba  BES    535.0
# 28                              Bosnia and Herzegovina  BIH     70.0
# 29                                            Botswana  BWA     72.0
# ..                                                 ...  ...      ...
# 222                                           Thailand  THA    764.0
# 223                                        Timor-Leste  TLS    626.0
# 224                                               Togo  TGO    768.0
# 225                                            Tokelau  TKL    772.0
# 226                                              Tonga  TON    776.0
# 227                                Trinidad and Tobago  TTO    780.0
# 228                                            Tunisia  TUN    788.0
# 229                                             Turkey  TUR    792.0
# 230                                       Turkmenistan  TKM    795.0
# 231                           Turks and Caicos Islands  TCA    796.0
# 232                                             Tuvalu  TUV    798.0
# 233                                             Uganda  UGA    800.0
# 234                                            Ukraine  UKR    804.0
# 235                               United Arab Emirates  ARE    784.0
# 236  United Kingdom of Great Britain and Northern I...  GBR    826.0
# 237                           United States of America  USA    840.0
# 238               United States Minor Outlying Islands  UMI    581.0
# 239                                            Uruguay  URY    858.0
# 240                                         Uzbekistan  UZB    860.0
# 241                                            Vanuatu  VUT    548.0
# 242                 Venezuela (Bolivarian Republic of)  VEN    862.0
# 243                                           Viet Nam  VNM    704.0
# 244                           Virgin Islands (British)  VGB     92.0
# 245                              Virgin Islands (U.S.)  VIR    850.0
# 246                                  Wallis and Futuna  WLF    876.0
# 247                                     Western Sahara  ESH    732.0
# 248                                              Yemen  YEM    887.0
# 249                                             Zambia  ZMB    894.0
# 250                                                NaN  NaN      NaN
# 251                                           Zimbabwe  ZWE    716.0
#
# [252 rows x 6 columns]

# %%
# iso_map

# %%
mortality_file= dir_path + 'data/meta_data/mortality_countries.csv'
mortality_countries = pd.read_csv(mortality_file)
mortality_countries.sort_values(by='iso', inplace=True)

# %%
mort_ls_of_countries
# Out:
#     iso     countryName
# 0   AUT         Austria
# 1   BEL         Belgium
# 2   BGR        Bulgaria
# 28  BRA          Brazil
# 29  CHL           Chile
# 4   CYP          Cyprus
# 5   CZE  Czech Republic
# 10  DEU         Germany
# 6   DNK         Denmark
# 25  ESP           Spain
# 7   EST         Estonia
# 8   FIN         Finland
# 9   FRA          France
# 30  FRA          France
# 27  GBR  United Kingdom
# 11  GRC          Greece
# 3   HRV         Croatia
# 12  HUN         Hungary
# 13  IRL         Ireland
# 14  ITA           Italy
# 31  JPN           Japan
# 16  LTU       Lithuania
# 17  LUX      Luxembourg
# 15  LVA          Latvia
# 32  MEX          Mexico
# 18  MLT           Malta
# 19  NLD     Netherlands
# 20  POL          Poland
# 21  PRT        Portugal
# 22  ROU         Romania
# 23  SVK        Slovakia
# 24  SVN        Slovenia
# 26  SWE          Sweden
# 33  USA   United States

# %%
iso_map.
